# %%
#boolean constructor bool()
# boolean literal True and False

# %%
print("hello world")
# Out:
# hello world

# %%
print=10

# %%
print(10)
# Out:
# 10

# %%
print
# Out:
# 10

# %%
del print

# %%
a=10
bool(a)
# Out:
# True

# %%
b=0.0
bool(b)
# Out:
# False

# %%
c=0.0000000000000000000000000000000000000000000001
bool(c)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
int()
# Out:
# 0

# %%
bool(str())

# %%
bool(float("10.0"))   bool(10.0)
